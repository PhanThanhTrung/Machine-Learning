# %%
import numpy as np
import cv2
import os
import copy

# %% [markdown]
# ### BÀI TẬP: Hãy tạo 2 danh sách (python list) chứa đường dẫn tuyệt đối và đường dẫn tương đối đến các tệp nằm trong thư mục 'image'

# %%
os.listdir('image')
# Out:
# ['3.jpg', '1.jpg', '4.jpg', '2.jpg', '5.jpg']

# %%
[os.path.join('image',i) for i in os.listdir('image')]
# Out:
# ['image/3.jpg', 'image/1.jpg', 'image/4.jpg', 'image/2.jpg', 'image/5.jpg']

# %%
[os.path.join(os.path.abspath('image'),i) for i in os.listdir('image')]
# Out:
# ['/home/phantrung/Documents/image/3.jpg',
#  '/home/phantrung/Documents/image/1.jpg',
#  '/home/phantrung/Documents/image/4.jpg',
#  '/home/phantrung/Documents/image/2.jpg',
#  '/home/phantrung/Documents/image/5.jpg']

# %% [markdown]
# ### Bài tập 2: Làm quen với thư viện Numpy và OpenCV

# %% [markdown]
# - Bài tập 2.1: Hiển thị các kênh màu của ảnh

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/home/phantrung/Documents/image/3.jpg')

# %%
r=img.copy()
r[:,:,1:3]=0

# %%
plt.imshow(r)

# %%
g_channel = img.copy()
g_channel[:, :, [0, 2]] = 0

# %%
plt.imshow(g)

# %%
b_channel = img.copy()
b_channel[:, :, [0,1]] = 0

# %%
plt.imshow(b_channel)

# %% [markdown]
# - Bài tập 2.2: Xây dựng vector histogram của ảnh xám

# %%
img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
histo=np.zeros(256,)

# %%
for i in img:
    for j in i:
        histo[j]+=1

# %%
plt.plot(histo)
